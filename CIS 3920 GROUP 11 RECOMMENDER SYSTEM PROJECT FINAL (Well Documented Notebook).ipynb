# %% [markdown]
# # CIS 3920 GROUP 11 RECOMMENDER SYSTEM PROJECT
# Sahiti Kovvuri, Kamilla Sharipova, Samantha Soto, Weiguang Wu

# %% [markdown]
# # importing all libraries

# %%
import pandas as pd 
import numpy as np
import ast 
from ast import literal_eval # converts strings into tuples for further data processing
import re #used to tokenize & lowercased data

import nltk
from nltk.corpus import stopwords #used for Porter Stemmer and NLTK processing 
nltk.download('stopwords') #NLTK (Natural Language Toolkit) includes a list of 40 stop words defined as 'stopwords' 

import seaborn as sns
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer #used to call Tfid vectorizer functions
from sklearn.feature_extraction.text import CountVectorizer #used to call count vectorizer functions
from sklearn.metrics.pairwise import cosine_similarity #used to call cosine similarity function
import string
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sahitikovvuri/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
! ls -l 'tmdb_5000_movies.csv' 'tmdb_5000_credits.csv'
# Out:
# -rw-r--r--@ 1 sahitikovvuri  staff  40044293 Nov 15 22:34 tmdb_5000_credits.csv
# -rw-r--r--@ 1 sahitikovvuri  staff   5722964 Nov 15 22:34 tmdb_5000_movies.csv

# %%
! wc -l 'tmdb_5000_movies.csv' 'tmdb_5000_credits.csv'
# Out:
#     4804 tmdb_5000_movies.csv
#     4804 tmdb_5000_credits.csv
#     9608 total

# %% [markdown]
# # data preparation using csv's

# %%
#reading tmdb_5000 movies and credits data files
movies_df = pd.read_csv('tmdb_5000_movies.csv')
credits_df = pd.read_csv('tmdb_5000_credits.csv')

# %%
#merging both data sets
credits_df.columns = ['id','title','cast','crew']
movies_df= movies_df.merge(credits_df,on='id')

# %%
print(movies_df)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  ... runtime  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4           [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
# ...                                                 ...  ...     ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]  ...    81.0
# 4799                                                 []  ...    85.0
# 4800  [{"name": "Front Street Pictures", "id": 3958}...  ...   120.0
# 4801                                                 []  ...    98.0
# 4802  [{"name": "rusty bear entertainment", "id": 87...  ...    90.0
#
#                                        spoken_languages    status  \
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1              [{"iso_639_1": "en", "name": "English"}]  Released
# 2     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3              [{"iso_639_1": "en", "name": "English"}]  Released
# 4              [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                 ...       ...
# 4798      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 4799                                                 []  Released
# 4800           [{"iso_639_1": "en", "name": "English"}]  Released
# 4801           [{"iso_639_1": "en", "name": "English"}]  Released
# 4802           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4798  He didn't come looking for trouble, but troubl...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800                                                NaN
# 4801                           A New Yorker in Shanghai
# 4802                                                NaN
#
#                                        title_x vote_average vote_count  \
# 0                                       Avatar          7.2      11800
# 1     Pirates of the Caribbean: At World's End          6.9       4500
# 2                                      Spectre          6.3       4466
# 3                        The Dark Knight Rises          7.6       9106
# 4                                  John Carter          6.1       2124
# ...                                        ...          ...        ...
# 4798                               El Mariachi          6.6        238
# 4799                                 Newlyweds          5.9          5
# 4800                 Signed, Sealed, Delivered          7.0          6
# 4801                          Shanghai Calling          5.7          7
# 4802                         My Date with Drew          6.3         16
#
#                                        title_y  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4798  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4800  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4801  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4802  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4803 rows x 23 columns]

# %% [markdown]
# # cleaning-up data

# %%
#removed newline (\n) characters in 'overview'
movies_df['overview'] = movies_df['overview'].str.replace(r'\n', '', regex=True)
movies_df.sample(10)
# Out:
#          budget                                             genres  \
# 32    200000000  [{"id": 10751, "name": "Family"}, {"id": 14, "...
# 1150   40000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 3942    3000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 1893   25000000  [{"id": 14, "name": "Fantasy"}, {"id": 27, "na...
# 2704          0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 4534     500000                [{"id": 99, "name": "Documentary"}]
# 3890          0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 1275   50000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 2809    7000000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
# 586    70000000  [{"id": 10752, "name": "War"}, {"id": 18, "nam...
#
#                                    homepage      id  \
# 32         http://disney.go.com/wonderland/   12155
# 1150   http://www.myspace.com/proposalmovie   18240
# 3942       http://www.hobowithashotgun.com/   49010
# 1893  http://www.dontbeafraidofthedark.com/   46261
# 2704                                    NaN    1123
# 4534          http://www.rickyjaymovie.com/  180383
# 3890                                    NaN   10162
# 1275                                    NaN    1272
# 2809                 http://www.jaws25.com/     578
# 586            http://www.monumentsmen.com/  152760
#
#                                                keywords original_language  \
# 32    [{"id": 818, "name": "based on novel"}, {"id":...                en
# 1150  [{"id": 1907, "name": "fictitious marriage"}, ...                en
# 3942  [{"id": 293, "name": "female nudity"}, {"id": ...                en
# 1893  [{"id": 1299, "name": "monster"}, {"id": 9714,...                en
# 2704  [{"id": 796, "name": "police brutality"}, {"id...                en
# 4534  [{"id": 2343, "name": "magic"}, {"id": 187056,...                en
# 3890  [{"id": 3864, "name": "false identity"}, {"id"...                en
# 1275  [{"id": 83, "name": "saving the world"}, {"id"...                en
# 2809  [{"id": 1495, "name": "fishing"}, {"id": 1913,...                en
# 586   [{"id": 1956, "name": "world war ii"}, {"id": ...                en
#
#                                          original_title  \
# 32                                  Alice in Wonderland
# 1150                                       The Proposal
# 3942                                Hobo with a Shotgun
# 1893                        Don't Be Afraid of the Dark
# 2704                                       Catch a Fire
# 4534  Deceptive Practice: The Mysteries and Mentors ...
# 3890                                         Waking Ned
# 1275                                           Sunshine
# 2809                                               Jaws
# 586                                   The Monuments Men
#
#                                                overview  popularity  \
# 32    Alice, an unpretentious and individual 19-year...   78.530105
# 1150  When she learns she's in danger of losing her ...   36.238968
# 3942  A vigilante homeless man pulls into a new city...   16.900433
# 1893  A young girl sent to live with her father and ...   14.562197
# 2704  The true story of anti-apartheid activists in ...    4.052219
# 4534  The life and career of renowned magician and s...    0.425195
# 3890  When a lottery winner dies of shock, his fello...    5.735912
# 1275  Fifty years into the future, the sun is dying,...   51.502884
# 2809  An insatiable great white shark terrorizes the...   50.152327
# 586   Based on the true story of the greatest treasu...   43.873266
#
#                                    production_companies  ... runtime  \
# 32    [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   108.0
# 1150  [{"name": "Touchstone Pictures", "id": 9195}, ...  ...   108.0
# 3942  [{"name": "Rhombus Media", "id": 164}, {"name"...  ...    86.0
# 1893  [{"name": "Miramax Films", "id": 14}, {"name":...  ...    99.0
# 2704  [{"name": "Mirage Enterprises", "id": 932}, {"...  ...   101.0
# 4534             [{"name": "Kino Lorber", "id": 39134}]  ...    88.0
# 3890  [{"name": "Fox Searchlight Pictures", "id": 43...  ...    91.0
# 1275  [{"name": "DNA Films", "id": 284}, {"name": "I...  ...   107.0
# 2809  [{"name": "Universal Pictures", "id": 33}, {"n...  ...   124.0
# 586   [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   118.0
#
#                                        spoken_languages    status  \
# 32             [{"iso_639_1": "en", "name": "English"}]  Released
# 1150           [{"iso_639_1": "en", "name": "English"}]  Released
# 3942           [{"iso_639_1": "en", "name": "English"}]  Released
# 1893           [{"iso_639_1": "en", "name": "English"}]  Released
# 2704  [{"iso_639_1": "af", "name": "Afrikaans"}, {"i...  Released
# 4534           [{"iso_639_1": "en", "name": "English"}]  Released
# 3890  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1275           [{"iso_639_1": "en", "name": "English"}]  Released
# 2809           [{"iso_639_1": "en", "name": "English"}]  Released
# 586   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                                          tagline  \
# 32      You're invited to a very important date.
# 1150                     Here comes the bribe...
# 3942  Delivering justice, one shell at a time...
# 1893             Fear is never just make believe
# 2704       The spark that ignites us, unites us.
# 4534                                         NaN
# 3890      How far would you go to win a fortune!
# 1275                  If the sun dies, so do we.
# 2809                      Don't go in the water.
# 586     It was the greatest art heist in history
#
#                                                 title_x vote_average  \
# 32                                  Alice in Wonderland          6.4
# 1150                                       The Proposal          6.7
# 3942                                Hobo with a Shotgun          5.7
# 1893                        Don't Be Afraid of the Dark          5.4
# 2704                                       Catch a Fire          6.4
# 4534  Deceptive Practice: The Mysteries and Mentors ...          7.1
# 3890                                         Waking Ned          7.4
# 1275                                           Sunshine          7.0
# 2809                                               Jaws          7.5
# 586                                   The Monuments Men          5.8
#
#      vote_count                                            title_y  \
# 32         4645                                Alice in Wonderland
# 1150       1804                                       The Proposal
# 3942        211                                Hobo with a Shotgun
# 1893        341                        Don't Be Afraid of the Dark
# 2704         25                                       Catch a Fire
# 4534         17  Deceptive Practice: The Mysteries and Mentors ...
# 3890         54                                         Waking Ned
# 1275       1182                                           Sunshine
# 2809       2542                                               Jaws
# 586        1523                                  The Monuments Men
#
#                                                    cast  \
# 32    [{"cast_id": 7, "character": "Alice Kingsleigh...
# 1150  [{"cast_id": 3, "character": "Margaret Tate", ...
# 3942  [{"cast_id": 2, "character": "Hobo", "credit_i...
# 1893  [{"cast_id": 10, "character": "Kim", "credit_i...
# 2704  [{"cast_id": 14, "character": "Nic Vos", "cred...
# 4534  [{"cast_id": 2, "character": "Himself", "credi...
# 3890  [{"cast_id": 9, "character": "Jackie O'Shea", ...
# 1275  [{"cast_id": 5, "character": "Robert Capa", "c...
# 2809  [{"cast_id": 15, "character": "Police Chief Ma...
# 586   [{"cast_id": 7, "character": "James Granger", ...
#
#                                                    crew
# 32    [{"credit_id": "52fe44c09251416c7503fbc3", "de...
# 1150  [{"credit_id": "5635d9db925141284c019df7", "de...
# 3942  [{"credit_id": "534275200e0a2679a1003b31", "de...
# 1893  [{"credit_id": "52fe46edc3a36847f811a321", "de...
# 2704  [{"credit_id": "52fe42e8c3a36847f802be69", "de...
# 4534  [{"credit_id": "547117cf92514123e30008b4", "de...
# 3890  [{"credit_id": "52fe43399251416c750082b9", "de...
# 1275  [{"credit_id": "5378a9080e0a261425004f95", "de...
# 2809  [{"credit_id": "52fe4255c3a36847f801603d", "de...
# 586   [{"credit_id": "53630586c3a3681568000c62", "de...
#
# [10 rows x 23 columns]

# %% [markdown]
# # handling missing data (NaN/null values)

# %%
#selects all rows with NaN in the overview column (handling missing data) 
movies_df[movies_df['overview'].isna()]

#saves the list into a dataframe called null_movies
null_movies = movies_df[movies_df['overview'].isna()] 

#displays the movie titles only in Null_movies
null_movies[['original_title','overview']] 

#handles missing overview data

#null value imputation named null
null = null_movies.loc[:, ['original_title', 'overview']]

#select the column for which the description will be imputed into named col_list
col_list =  list(null["original_title"])
descrip = ["Set within a year after the events of Batman Begins, Batman, Lieutenant James Gordon, and new District Attorney Harvey Dent successfully begin to round up the criminals that plague Gotham City, until a mysterious and sadistic criminal mastermind known only as 'The Joker' appears in Gotham, creating a new wave of chaos. Batman's struggle against The Joker becomes deeply personal, forcing him to confront everything he believes and improve his technology to stop him. A love triangle develops between Bruce Wayne, Dent, and Rachel Dawes.",
          "Growing up can be a bumpy road, and it's no exception for Riley, who is uprooted from her Midwest life when her father starts a new job in San Francisco. Like all of us, Riley is guided by her emotions - Joy, Fear, Anger, Disgust and Sadness. The emotions live in Headquarters, the control center inside Riley's mind, where they help advise her through everyday life. As Riley and her emotions struggle to adjust to a new life in San Francisco, turmoil ensues in Headquarters. Although Joy, Riley's main and most important emotion, tries to keep things positive, the emotions conflict on how best to navigate a new city, house and school.",
          "Andrew Neiman (Miles Teller) is an ambitious young jazz drummer, in pursuit of rising to the top of his elite music conservatory. Terence Fletcher (J.K. Simmons), an instructor known for his terrifying teaching methods, discovers Andrew and transfers the aspiring drummer into the top jazz ensemble, forever changing the young man's life. But Andrew's passion to achieve perfection quickly spirals into obsession, as his ruthless teacher pushes him to the brink of his ability and his sanity",
          "The life of Frank Sinatra, as an actor and singer and the steps along the way that led him to become such an icon.",
          "To protest their working conditions and poor wages, farmworkers in Immokalee, Florida, start a hunger strike outside the headquarters of Publix supermarkets."]
#saves missing overviews in a dictionary 
overviews = pd.DataFrame({'original_title': col_list, 
                          'overview': descrip})
#modifies original dataframe inputting the missing overviews
movies_df['overview']=movies_df['overview'].apply(lambda x: x if x == x else overviews)

# %%
#displays data after inputting missing overviews
movies_df.sample(5)
# Out:
#         budget                                             genres  \
# 3817    967686  [{"id": 35, "name": "Comedy"}, {"id": 80, "nam...
# 4456    800000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4122  13500000                      [{"id": 18, "name": "Drama"}]
# 2990  10000000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
# 1910         0  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
#
#                                  homepage      id  \
# 3817         http://www.four-lions.co.uk/   37495
# 4456        http://www.lhp.com.sg/victor/   25461
# 4122  https://twitter.com/Stonewall_Movie  273899
# 2990                                  NaN    8922
# 1910                                  NaN   10074
#
#                                                keywords original_language  \
# 3817  [{"id": 13015, "name": "terrorism"}, {"id": 19...                en
# 4456        [{"id": 10183, "name": "independent film"}]                en
# 4122         [{"id": 173510, "name": "stonewall riot"}]                en
# 2990  [{"id": 1583, "name": "mass murder"}, {"id": 4...                en
# 1910  [{"id": 5956, "name": "stuntman"}, {"id": 6669...                en
#
#              original_title  \
# 3817             Four Lions
# 4456  Raising Victor Vargas
# 4122              Stonewall
# 2990       Jeepers Creepers
# 1910                Hot Rod
#
#                                                overview  popularity  \
# 3817  Four Lions tells the story of a group of Briti...   20.544999
# 4456  The film follows Victor, a Lower East Side tee...    3.643662
# 4122  "Stonewall" is a drama about a young man in Ne...    5.160230
# 2990  A college-age brother and sister get more than...   23.316208
# 1910  For Rod Kimball, performing stunts is a way of...    6.309587
#
#                                    production_companies  ... runtime  \
# 3817  [{"name": "Film4", "id": 9349}, {"name": "Draf...  ...   101.0
# 4456                                                 []  ...    88.0
# 4122  [{"name": "Centropolis Entertainment", "id": 3...  ...   129.0
# 2990  [{"name": "United Artists", "id": 60}, {"name"...  ...    90.0
# 1910          [{"name": "Paramount Pictures", "id": 4}]  ...    88.0
#
#                                        spoken_languages    status  \
# 3817  [{"iso_639_1": "ar", "name": "\u0627\u0644\u06...  Released
# 4456  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 4122           [{"iso_639_1": "en", "name": "English"}]  Released
# 2990           [{"iso_639_1": "en", "name": "English"}]  Released
# 1910           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                          tagline                title_x vote_average  \
# 3817             We are 4 Lions.             Four Lions          7.0
# 4456                         NaN  Raising Victor Vargas          7.8
# 4122           Where Pride Began              Stonewall          5.2
# 2990          What’s eating you?       Jeepers Creepers          6.1
# 1910  Smack destiny in the face.                Hot Rod          6.3
#
#      vote_count                title_y  \
# 3817        423             Four Lions
# 4456         13  Raising Victor Vargas
# 4122         32              Stonewall
# 2990        720       Jeepers Creepers
# 1910        313                Hot Rod
#
#                                                    cast  \
# 3817  [{"cast_id": 5, "character": "Omar", "credit_i...
# 4456  [{"cast_id": 3, "character": "Victor Vargas", ...
# 4122  [{"cast_id": 2, "character": "Danny", "credit_...
# 2990  [{"cast_id": 10, "character": "Patricia 'Trish...
# 1910  [{"cast_id": 22, "character": "Rod Kimble", "c...
#
#                                                    crew
# 3817  [{"credit_id": "536befdfc3a368124100a6e6", "de...
# 4456  [{"credit_id": "58d0f315c3a36838af008913", "de...
# 4122  [{"credit_id": "538f48c8c3a3680d7500021b", "de...
# 2990  [{"credit_id": "52fe44c8c3a36847f80a9c27", "de...
# 1910  [{"credit_id": "52fe431d9251416c75003f95", "de...
#
# [5 rows x 23 columns]

# %%
#checks if there are any null values after imputing
movies_df[movies_df['overview'].isna()]
# Out:
# Empty DataFrame
# Columns: [budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title_x, vote_average, vote_count, title_y, cast, crew]
# Index: []
#
# [0 rows x 23 columns]

# %%
#changed ‘overview’ type to string 
movies_df['overview'] = movies_df['overview'].astype(str)

# %% [markdown]
# # text mining preprocessing technique (1): removing punctuation

# %%
#function to remove punctuation from 'overview'
string.punctuation
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct

# Remove punctuation from data
movies_df['overview'] = movies_df['overview'].apply(lambda x: remove_punct(x))
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century a paraplegic Marine is dis...  150.437577
# 1  Captain Barbossa long believed to be dead has ...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a warweary former military capt...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                     title_x vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %% [markdown]
# # text mining preprocessing technique (2): tokenizing strings

# %%
#function to tokenize 
def tokenize(text):
    tokens = re.split('\W+', text)
    return tokens

movies_df['overview'] = movies_df['overview'].apply(lambda x: tokenize(x))

#display overview with new overview column
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  [In, the, 22nd, century, a, paraplegic, Marine...  150.437577
# 1  [Captain, Barbossa, long, believed, to, be, de...  139.082615
# 2  [A, cryptic, message, from, Bond, s, past, sen...  107.376788
# 3  [Following, the, death, of, District, Attorney...  112.312950
# 4  [John, Carter, is, a, warweary, former, milita...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                     title_x vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %% [markdown]
# # text mining preprocessing technique (3): handling lowercased strings

# %%
#changed ‘overview’ type to string again (was getting error “AttributeError: 'list' object has no attribute 'lower'”)
movies_df['overview'] = movies_df['overview'].astype(str)

# %%
# adds the column with tokenized & lowercased data 
movies_df['overview'] = movies_df['overview'].apply(lambda x: tokenize(x.lower())) 

#display overview with new overview column
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  [, in, the, 22nd, century, a, paraplegic, mari...  150.437577
# 1  [, captain, barbossa, long, believed, to, be, ...  139.082615
# 2  [, a, cryptic, message, from, bond, s, past, s...  107.376788
# 3  [, following, the, death, of, district, attorn...  112.312950
# 4  [, john, carter, is, a, warweary, former, mili...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                     title_x vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %% [markdown]
# # text mining preprocessing technique (4): handling stopwords using NLTK

# %%
#removing english stop words such as 'a', 'the', 'was', 'in', etc
stopwords = nltk.corpus.stopwords.words('english') 

#function to remove stop words called remove_stopwords 
def remove_stopwords(tokenized_list):
    text = [word for word in tokenized_list if word not in stopwords]
    return text

# removes stop words from data & adds a column to the right with data 
# no stop words present in overview_clean2
movies_df['overview'] = movies_df['overview'].apply(lambda x: remove_stopwords(x))


#display overview with new overview column
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  [, 22nd, century, paraplegic, marine, dispatch...  150.437577
# 1  [, captain, barbossa, long, believed, dead, co...  139.082615
# 2  [, cryptic, message, bond, past, sends, trail,...  107.376788
# 3  [, following, death, district, attorney, harve...  112.312950
# 4  [, john, carter, warweary, former, military, c...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                     title_x vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %% [markdown]
# # text mining preprocessing technique (5): cut words using Porter Stemmer

# %%
#defining the porter stemmer
stemmer = nltk.PorterStemmer()

#create function to apply stemmer
def stemming(tokenized_text):
    text = [stemmer.stem(word) for word in tokenized_text]
    return text

#apply Porter Stemmer
movies_df['overview'] = movies_df['overview'].apply(lambda x: stemming(x))

#display overview with new overview column
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  [, 22nd, centuri, parapleg, marin, dispatch, m...  150.437577
# 1  [, captain, barbossa, long, believ, dead, come...  139.082615
# 2  [, cryptic, messag, bond, past, send, trail, u...  107.376788
# 3  [, follow, death, district, attorney, harvey, ...  112.312950
# 4  [, john, carter, warweari, former, militari, c...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                     title_x vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
#changed ‘overview’ type to string again (was getting error “AttributeError: 'list' object has no attribute 'lower'”)
movies_df['overview'] = movies_df['overview'].astype(str)

# %% [markdown]
# # vectorization technique (1): calculate the TF-IDF score vectorizer using overview

# %%
# Calculate the TF-IDF score for each word in overview, word by word
tfidf = TfidfVectorizer(analyzer='word', stop_words='english')#removing stop words like 'the' and 'a'

# overview_matrix variable where we store the matrix containing each word and 
#its TF-IDF score with regard to each word in overview
overview_matrix = tfidf.fit_transform(movies_df['overview'])
overview_matrix
# Out:
# <4803x16717 sparse matrix of type '<class 'numpy.float64'>'
# 	with 128238 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # creating a new feature with spoken_languages, keywords, genres, cast, crew

# %%
features = ['spoken_languages', 'keywords', 'genres', 'cast','crew']

# %%
#converting string list features in tuples
for feature in features: movies_df[feature] = movies_df[feature].apply(lambda x: literal_eval(str(x)))

# %%
#merged the strings by defining get_list
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        if len(names) > 2:
            names = names[:2] #only take first 2  names
        return names

# %% [markdown]
# # similarity metric technique (1): cosine

# %%
cosine_sim2 = linear_kernel(overview_matrix, overview_matrix)

# %%
#first three features are from tmdb_5000_credits.csv, "cast" feature is from tmdb_5000_movies.csv
for feature in features:
    movies_df[feature] = movies_df[feature].apply(get_list) #turn into list

# %%
movies_df[['original_title','spoken_languages', 'keywords', 'genres', 'cast','crew']].sample(5)
#these are the features we are going to work with (excluding original_title)
# Out:
#             original_title     spoken_languages                     keywords  \
# 1274         Just Visiting  [English, Français]        [time travel, remake]
# 3979          Freakonomics            [English]  [female nudity, corruption]
# 3254   Akeelah and the Bee            [English]     [black people, spelling]
# 3222           Bright Star  [Français, English]     [poet, independent film]
# 2193  Secret in Their Eyes            [English]         [fbi, missing child]
#
#                  genres                               cast  \
# 1274  [Comedy, Fantasy]   [Jean Reno, Christina Applegate]
# 3979      [Documentary]        [Zoe Sloane, Jade Viggiano]
# 3254            [Drama]  [Keke Palmer, Laurence Fishburne]
# 3222   [Drama, Romance]       [Abbie Cornish, Ben Whishaw]
# 2193     [Crime, Drama]  [Chiwetel Ejiofor, Nicole Kidman]
#
#                                        crew
# 1274        [Suzanne Smith, Patrice Ledoux]
# 3979             [Heidi Ewing, Heidi Ewing]
# 3254              [Jaki Brown, Kim Coleman]
# 3222  [David M. Thompson, François Ivernel]
# 2193              [Mark Johnson, Billy Ray]

# %%
# reference --> O'Reilly "Hands on Reccomendation Systems"
#creating a soup out of the metadata to join the combined features in a single string
def rec_features(x):
    return ' '.join(x['spoken_languages']) + '  '.join(x['keywords']) + '  '.join(x['genres']) + '  '.join(x['cast']) + '  '.join(x['crew'])# + ' ' + ' '.join(x['overview'])
movies_df['rec_features'] = movies_df.apply(rec_features, axis=1)

# %%
print(movies_df)
# Out:
#          budget                genres  \
# 0     237000000   [Action, Adventure]
# 1     300000000  [Adventure, Fantasy]
# 2     245000000   [Action, Adventure]
# 3     250000000       [Action, Crime]
# 4     260000000   [Action, Adventure]
# ...         ...                   ...
# 4798     220000       [Action, Crime]
# 4799       9000     [Comedy, Romance]
# 4800          0       [Comedy, Drama]
# 4801          0                    []
# 4802          0         [Documentary]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                   keywords original_language  \
# 0                  [culture clash, future]                en
# 1                      [ocean, drug abuse]                en
# 2                    [spy, based on novel]                en
# 3               [dc comics, crime fighter]                en
# 4                   [based on novel, mars]                en
# ...                                    ...               ...
# 4798  [united states–mexico barrier, legs]                es
# 4799                                    []                en
# 4800           [date, love at first sight]                en
# 4801                                    []                en
# 4802                [obsession, camcorder]                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     ['', '22nd', 'centuri', 'parapleg', 'marin', '...  150.437577
# 1     ['', 'captain', 'barbossa', 'long', 'believ', ...  139.082615
# 2     ['', 'cryptic', 'messag', 'bond', 'past', 'sen...  107.376788
# 3     ['', 'follow', 'death', 'district', 'attorney'...  112.312950
# 4     ['', 'john', 'carter', 'warweari', 'former', '...   43.926995
# ...                                                 ...         ...
# 4798  ['', 'el', 'mariachi', 'want', 'play', 'guitar...   14.269792
# 4799  ['', 'newlyw', 'coupl', 'honeymoon', 'upend', ...    0.642552
# 4800  ['', 'sign', 'seal', 'deliv', 'introduc', 'ded...    1.444476
# 4801  ['', 'ambiti', 'new', 'york', 'attorney', 'sam...    0.857008
# 4802  ['', 'ever', 'sinc', 'second', 'grade', 'first...    1.929883
#
#                                    production_companies  ...  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...  ...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]  ...
# ...                                                 ...  ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]  ...
# 4799                                                 []  ...
# 4800  [{"name": "Front Street Pictures", "id": 3958}...  ...
# 4801                                                 []  ...
# 4802  [{"name": "rusty bear entertainment", "id": 87...  ...
#
#          spoken_languages    status  \
# 0      [English, Español]  Released
# 1               [English]  Released
# 2     [Français, English]  Released
# 3               [English]  Released
# 4               [English]  Released
# ...                   ...       ...
# 4798            [Español]  Released
# 4799                   []  Released
# 4800            [English]  Released
# 4801            [English]  Released
# 4802            [English]  Released
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4798  He didn't come looking for trouble, but troubl...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800                                                NaN
# 4801                           A New Yorker in Shanghai
# 4802                                                NaN
#
#                                        title_x vote_average vote_count  \
# 0                                       Avatar          7.2      11800
# 1     Pirates of the Caribbean: At World's End          6.9       4500
# 2                                      Spectre          6.3       4466
# 3                        The Dark Knight Rises          7.6       9106
# 4                                  John Carter          6.1       2124
# ...                                        ...          ...        ...
# 4798                               El Mariachi          6.6        238
# 4799                                 Newlyweds          5.9          5
# 4800                 Signed, Sealed, Delivered          7.0          6
# 4801                          Shanghai Calling          5.7          7
# 4802                         My Date with Drew          6.3         16
#
#                                        title_y  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                     cast  \
# 0         [Sam Worthington, Zoe Saldana]
# 1           [Johnny Depp, Orlando Bloom]
# 2        [Daniel Craig, Christoph Waltz]
# 3        [Christian Bale, Michael Caine]
# 4          [Taylor Kitsch, Lynn Collins]
# ...                                  ...
# 4798   [Carlos Gallardo, Jaime de Hoyos]
# 4799         [Edward Burns, Kerry Bishé]
# 4800        [Eric Mabius, Kristin Booth]
# 4801        [Daniel Henney, Eliza Coupe]
# 4802  [Drew Barrymore, Brian Herzlinger]
#
#                                       crew  \
# 0         [Stephen E. Rivkin, Rick Carter]
# 1         [Dariusz Wolski, Gore Verbinski]
# 2              [Thomas Newman, Sam Mendes]
# 3             [Hans Zimmer, Charles Roven]
# 4         [Andrew Stanton, Andrew Stanton]
# ...                                    ...
# 4798  [Robert Rodriguez, Robert Rodriguez]
# 4799          [Edward Burns, Edward Burns]
# 4800          [Carla Hetland, Harvey Kahn]
# 4801            [Daniel Hsia, Daniel Hsia]
# 4802       [Clark Peterson, Andrew Reimer]
#
#                                            rec_features
# 0     English Españolculture clash  futureAction  Ad...
# 1     Englishocean  drug abuseAdventure  FantasyJohn...
# 2     Français Englishspy  based on novelAction  Adv...
# 3     Englishdc comics  crime fighterAction  CrimeCh...
# 4     Englishbased on novel  marsAction  AdventureTa...
# ...                                                 ...
# 4798  Españolunited states–mexico barrier  legsActio...
# 4799  Comedy  RomanceEdward Burns  Kerry BishéEdward...
# 4800  Englishdate  love at first sightComedy  DramaE...
# 4801  EnglishDaniel Henney  Eliza CoupeDaniel Hsia  ...
# 4802  Englishobsession  camcorderDocumentaryDrew Bar...
#
# [4803 rows x 24 columns]

# %% [markdown]
# # vectorization technique (2): count vectorizer using features

# %%
countVec = CountVectorizer(analyzer='word', stop_words='english') 
#removing unnecessary stop words
#in order to extract features from our data, must use fit.transform to 
#count the number of texts and make teh transformed matrix (keyword_matrix) into an array
keyword_matrix = countVec.fit_transform(movies_df['rec_features'])

# %%
#measures distance between similarities of movie features chosen
cosine_sim = cosine_similarity(keyword_matrix, keyword_matrix)

# %%
# Reset index of main dataframe and reconstruct data frame to mirror output results
movies_df = movies_df.reset_index()
movies = pd.Series(movies_df.index, index=movies_df['original_title'])

# %%
cosine_sim3 = cosine_similarity(cosine_sim, cosine_sim2)

# %% [markdown]
# # define recommendation function get_recommendations

# %%
def get_recommendations(title, cosine_sim3=cosine_sim3):
    # index of the movie with that title
    recommendation = movies[title]
    # pairwise similarity scores of all movies with that movie
    similarity = list(enumerate(cosine_sim3[recommendation]))
    # sorts movies based on similarity score
    similarity = sorted(similarity, key=lambda x: x[1], reverse=True)
    # gets scores of 5 most similar movies
    similarity = similarity[1:6]
    # gets the index of the similar movies
    movie_recommendation = [i[0] for i in similarity]
    # return top 5 most similar movies
    return movies_df['original_title'].iloc[movie_recommendation]

# %% [markdown]
# # allow user to input movie for recommendations > user interface (creativity)

# %%
movie = input('Enter a movie for recommendations(and press enter): ')

# %%
#display recommendations
get_recommendations(movie, cosine_sim)

# %% [markdown]
# # get recommendations for The Dark Knight, The Shawshank Redemption and Frozen

# %%
get_recommendations('The Dark Knight', cosine_sim)

# %%
get_recommendations('The Shawshank Redemption', cosine_sim)

# %%
get_recommendations('Frozen', cosine_sim)

# %%
#REFERENCES
#https://stackoverflow.com/questions/12453580/how-to-concatenate-join-items-in-a-list-to-a-single-string
#https://www.nltk.org/_modules/nltk/stem/wordnet.html
#25_NB_2.pynb 
#13_TM_2.pynb for preprocessing techniques
